# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
clean_wine="Resources/clean_winemag_data.csv"
apclean_wine_df=pd.read_csv(clean_wine)

# %%
apclean_wine_df.head()
# Out:
#    Unnamed: 0                                        Bottle Name  \
# 0           1      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           2      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2           3  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#                  Type               Winery  \
# 0      Portuguese Red  Quinta dos Avidagos
# 1          Pinot Gris            Rainstorm
# 2            Riesling           St. Julian
# 3          Pinot Noir         Sweet Cheeks
# 4  Tempranillo-Merlot               Tandem
#
#                           Designation               Region        Province  \
# 0                            Avidagos                  NaN           Douro
# 1                                 NaN    Willamette Valley          Oregon
# 2                Reserve Late Harvest  Lake Michigan Shore        Michigan
# 3  Vintner's Reserve Wild Child Block    Willamette Valley          Oregon
# 4                        Ars In Vitro              Navarra  Northern Spain
#
#     Country  Price  Rating           Sommelier Sommelier Twitter Handle  \
# 0  Portugal   15.0    87.0          Roger Voss               @vossroger
# 1        US   14.0    87.0        Paul Gregutt              @paulgwine
# 2        US   13.0    87.0  Alexander Peartree                      NaN
# 3        US   65.0    87.0        Paul Gregutt              @paulgwine
# 4     Spain   15.0    87.0   Michael Schachner              @wineschach
#
#                                          Description
# 0  This is ripe and fruity, a wine that is smooth...
# 1  Tart and snappy, the flavors of lime flesh and...
# 2  Pineapple rind, lemon pith and orange blossom ...
# 3  Much like the regular bottling from 2012, this...
# 4  Blackberry and raspberry aromas show a typical...

# %%
# The correlation coefficient between "Country" and "Price"


country_price_df = apclean_wine_df[['Bottle Name','Country','Price']]
sorted_df = country_price_df.sort_values('Price', ascending=False)
sorted_df.head(30)
# Out:
#                                               Bottle Name    Country   Price
# 74641                Château les Ormes Sorbet 2013  Médoc     France  3300.0
# 91505      Domaine du Comte Liger-Belair 2010  La Romanée     France  2500.0
# 14738                        Château Pétrus 2014  Pomerol     France  2500.0
# 111978  Blair 2013 Roger Rose Vineyard Chardonnay (Arr...         US  2013.0
# 60656                        Château Pétrus 2011  Pomerol     France  2000.0
# 105586     Domaine du Comte Liger-Belair 2005  La Romanée     France  2000.0
# 1471                        Château Margaux 2009  Margaux     France  1900.0
# 103926           Château Lafite Rothschild 2010  Pauillac     France  1500.0
# 103928           Château Cheval Blanc 2010  Saint-Émilion     France  1500.0
# 1487             Château Mouton Rothschild 2009  Pauillac     France  1300.0
# 1484              Château Haut-Brion 2009  Pessac-Léognan     France  1200.0
# 105599     Domaine du Comte Liger-Belair 2006  La Romanée     France  1125.0
# 1479    Château La Mission Haut-Brion 2009  Pessac-Léo...     France  1100.0
# 83216   Emmerich Knoll 2013 Ried Loibenberg Smaragd Gr...    Austria  1100.0
# 64547   Château La Mission Haut-Brion 2009  Pessac-Léo...     France  1000.0
# 33866       W. & J. Graham's NV 90-year Old Tawny  (Port)   Portugal  1000.0
# 38454                   Kopke 1935 Colheita White  (Port)   Portugal   980.0
# 78864                Domaine Jacques Prieur 2014  Musigny     France   973.0
# 50460             Château Haut-Brion 2013  Pessac-Léognan     France   932.0
# 82652   Biondi Santi 2006 Riserva  (Brunello di Montal...      Italy   900.0
# 27939                   Olivier Leflaive 2014  Montrachet     France   886.0
# 115739                 Château Ausone 2007  Saint-Émilion     France   850.0
# 52939       Penfolds 2010 Grange Shiraz (South Australia)  Australia   850.0
# 71559       Penfolds 2008 Grange Shiraz (South Australia)  Australia   850.0
# 114360            Château Haut-Brion 2014  Pessac-Léognan     France   848.0
# 52945    Henschke 2010 Hill of Grace Shiraz (Eden Valley)  Australia   820.0
# 105940                    Château d'Yquem 2005  Sauternes     France   800.0
# 100903  Biondi Santi 2007 Riserva  (Brunello di Montal...      Italy   800.0
# 36434             Château Haut-Brion 2007  Pessac-Léognan     France   800.0
# 90359    Domaine Pellé 2014 Morogues Rosé (Menetou-Salon)     France   800.0

# %%
# The Pearson correlation coefficient between "Rating" and "Price"

rating = apclean_wine_df.iloc[:,9]
price = apclean_wine_df.iloc[:,8]
correlation = st.pearsonr(rating,price)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.42

# %%
#Best wine in each price bracket
