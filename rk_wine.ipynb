# %%
#Dependencies
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.stats import pearsonr
import scipy.stats as st
import seaborn as sns
# pd.set_option('display.max_rows', None)

# %%
# Bring in CSV and Read in the File
file = Path("../Resources/clean_winemag_data.csv")
wine_df = pd.read_csv(file, index_col=0)

#Display Data Frame
wine_df.head()
# Out:
#                                          Bottle Name                Type  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 Winery                         Designation  \
# 1  Quinta dos Avidagos                            Avidagos
# 2            Rainstorm                                 NaN
# 3           St. Julian                Reserve Late Harvest
# 4         Sweet Cheeks  Vintner's Reserve Wild Child Block
# 5               Tandem                        Ars In Vitro
#
#                 Region        Province   Country  Price  Rating  \
# 1                  NaN           Douro  Portugal   15.0    87.0
# 2    Willamette Valley          Oregon        US   14.0    87.0
# 3  Lake Michigan Shore        Michigan        US   13.0    87.0
# 4    Willamette Valley          Oregon        US   65.0    87.0
# 5              Navarra  Northern Spain     Spain   15.0    87.0
#
#             Sommelier Sommelier Twitter Handle  \
# 1          Roger Voss               @vossroger
# 2        Paul Gregutt              @paulgwine
# 3  Alexander Peartree                      NaN
# 4        Paul Gregutt              @paulgwine
# 5   Michael Schachner              @wineschach
#
#                                          Description
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
# 5  Blackberry and raspberry aromas show a typical...

# %%
# count of all the values in the df
wine_df.count()
# Out:
# Bottle Name                 120915
# Type                        120915
# Winery                      120915
# Designation                  86148
# Region                      101400
# Province                    120915
# Country                     120915
# Price                       120915
# Rating                      120915
# Sommelier                    96420
# Sommelier Twitter Handle     91500
# Description                 120915
# dtype: int64

# %%
#Take the top 10 wine types from the DataFrame wine_df 
#Turn it into a list
my_sample = list(wine_df["Type"].value_counts()[:10].index)

my_sample
# Out:
# ['Pinot Noir',
#  'Chardonnay',
#  'Cabernet Sauvignon',
#  'Red Blend',
#  'Bordeaux-style Red Blend',
#  'Riesling',
#  'Sauvignon Blanc',
#  'Syrah',
#  'Rosé',
#  'Merlot']

# %%
#How many ratings are in each wine type
top_ten_types = wine_df["Type"].value_counts()[:10]

top_ten_types
# Out:
# Pinot Noir                  12785
# Chardonnay                  11077
# Cabernet Sauvignon           9384
# Red Blend                    8466
# Bordeaux-style Red Blend     5340
# Riesling                     4971
# Sauvignon Blanc              4780
# Syrah                        4086
# Rosé                         3261
# Merlot                       3061
# Name: Type, dtype: int64

# %%
#New DataFrame with "Type" values that match in my_sample list
sample_df = wine_df[wine_df["Type"].isin(my_sample)]
sample_df
# Out:
#                                               Bottle Name  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 10      Kirkland Signature 2011 Mountain Cuvée Caberne...
# 12      Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 14               Mirassou 2012 Chardonnay (Central Coast)
# ...                                                   ...
# 129958             Babich 2010 Irongate Red (Hawke's Bay)
# 129960  Caves Transmontanas 2006 Vértice Pinot Noir (D...
# 129963  Dalton 2012 Oak Aged Cabernet Sauvignon (Galilee)
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967                  Citation 2004 Pinot Noir (Oregon)
#
#                             Type                                    Winery  \
# 3                       Riesling                                St. Julian
# 4                     Pinot Noir                              Sweet Cheeks
# 10            Cabernet Sauvignon                        Kirkland Signature
# 12            Cabernet Sauvignon                          Louis M. Martini
# 14                    Chardonnay                                  Mirassou
# ...                          ...                                       ...
# 129958  Bordeaux-style Red Blend                                    Babich
# 129960                Pinot Noir                       Caves Transmontanas
# 129963        Cabernet Sauvignon                                    Dalton
# 129966                  Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                Pinot Noir                                  Citation
#
#                                    Designation               Region  \
# 3                         Reserve Late Harvest  Lake Michigan Shore
# 4           Vintner's Reserve Wild Child Block    Willamette Valley
# 10                              Mountain Cuvée          Napa Valley
# 12                                         NaN     Alexander Valley
# 14                                         NaN        Central Coast
# ...                                        ...                  ...
# 129958                                Irongate                  NaN
# 129960                                 Vértice                  NaN
# 129963                                Oak Aged                  NaN
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese                  NaN
# 129967                                     NaN               Oregon
#
#            Province      Country  Price  Rating           Sommelier  \
# 3          Michigan           US   13.0    87.0  Alexander Peartree
# 4            Oregon           US   65.0    87.0        Paul Gregutt
# 10       California           US   19.0    87.0      Virginie Boone
# 12       California           US   34.0    87.0      Virginie Boone
# 14       California           US   12.0    87.0       Matt Kettmann
# ...             ...          ...    ...     ...                 ...
# 129958  Hawke's Bay  New Zealand   35.0    90.0      Joe Czerwinski
# 129960        Douro     Portugal   48.0    90.0          Roger Voss
# 129963      Galilee       Israel   20.0    90.0       Mike DeSimone
# 129966        Mosel      Germany   28.0    90.0  Anna Lee C. Iijima
# 129967       Oregon           US   75.0    90.0        Paul Gregutt
#
#        Sommelier Twitter Handle  \
# 3                           NaN
# 4                   @paulgwine
# 10                      @vboone
# 12                      @vboone
# 14                @mattkettmann
# ...                         ...
# 129958                   @JoeCz
# 129960               @vossroger
# 129963           @worldwineguys
# 129966                      NaN
# 129967              @paulgwine
#
#                                               Description
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 10      Soft, supple plum envelopes an oaky structure ...
# 12      Slightly reduced, this wine offers a chalky, t...
# 14      Building on 150 years and six generations of w...
# ...                                                   ...
# 129958  This blend of Cabernet Sauvignon-Merlot and Ca...
# 129960  Fresh and fruity, this is full of red cherry f...
# 129963  A bouquet of black cherry, tart cranberry and ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
#
# [67211 rows x 12 columns]

# %%
#DataFrame of top bottles of the top ten wine types rated and correlations
#Empty list for wine correlations
results = []

#Looping through each of the 10 wines to find its correlation (price and rating)
for t in my_sample:
    temp_df = wine_df[wine_df["Type"] == t]
    temp_corr = temp_df[["Price" , "Rating"]].corr()
    c = temp_corr.iloc[1,0]
    result = {"Wine Types": t, "Correlation": c}
    results.append(result)

wine_corr = pd.DataFrame(results).sort_values(by="Correlation", ascending=False,)
wine_corr
# Out:
#                  Wine Types  Correlation
# 2        Cabernet Sauvignon     0.556685
# 6           Sauvignon Blanc     0.530771
# 3                 Red Blend     0.462397
# 9                    Merlot     0.440685
# 1                Chardonnay     0.429073
# 7                     Syrah     0.397914
# 5                  Riesling     0.397714
# 0                Pinot Noir     0.375345
# 4  Bordeaux-style Red Blend     0.351368
# 8                      Rosé     0.262412

# %%
#Save DataFrame
wine_corr.to_csv("../Resources/results.csv" , index=False)

# %%
#Creating a bar chart for the correlation of price and wines of the top ten wine types 

colors = ["darkred", "lemonchiffon", "darkred", "darkred", "lemonchiffon", "darkred", "lemonchiffon", "darkred", "darkred", "palevioletred"]

#Bar chart
plt.bar(wine_corr["Wine Types"], wine_corr["Correlation"], color = colors, edgecolor = "black")

# Set legend based on wine color using mpatches
red_patch = mpatches.Patch(color='darkred', edgecolor='black', label="Red")
white_patch = mpatches.Patch(color='lemonchiffon', edgecolor='black', label="White")
pink_patch = mpatches.Patch(color='palevioletred', edgecolor='black', label="Pink")
handles = [red_patch, white_patch, pink_patch]

# Add labels and title
plt.xlabel("Wine Types")
plt.ylabel("Correlation")
plt.title("Correlation Between Price and Rating by Top 10 Wine Types")
plt.legend(
    title = "Wine Color",
    handles = handles, 
    loc = 'best'
)

plt.xticks(rotation=90)

plt.show()
# Out:
# /var/folders/_s/xr22rb0d74l36001gkdblyy80000gp/T/ipykernel_3191/3220020466.py:9: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   red_patch = mpatches.Patch(color='darkred', edgecolor='black', label="Red")
# /var/folders/_s/xr22rb0d74l36001gkdblyy80000gp/T/ipykernel_3191/3220020466.py:10: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   white_patch = mpatches.Patch(color='lemonchiffon', edgecolor='black', label="White")
# /var/folders/_s/xr22rb0d74l36001gkdblyy80000gp/T/ipykernel_3191/3220020466.py:11: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   pink_patch = mpatches.Patch(color='palevioletred', edgecolor='black', label="Pink")

# %%
#Saving the Image
plt.savefig("../Resources/wine_bar_chart_rk.png")

# %%
#Correlation of all Top Ten Wine Types
all_corr = pearsonr(sample_df["Price"], sample_df["Rating"])

all_corr
# Out:
# PearsonRResult(statistic=0.40493499144875433, pvalue=0.0)

# %%
#Correlation of Wine Types from condesned DataFrame
sample_df.groupby("Type")["Price", "Rating"].corr().reset_index()
# Out:
# /var/folders/_s/xr22rb0d74l36001gkdblyy80000gp/T/ipykernel_3191/3386641889.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sample_df.groupby("Type")["Price", "Rating"].corr().reset_index()
#                         Type level_1     Price    Rating
# 0   Bordeaux-style Red Blend   Price  1.000000  0.351368
# 1   Bordeaux-style Red Blend  Rating  0.351368  1.000000
# 2         Cabernet Sauvignon   Price  1.000000  0.556685
# 3         Cabernet Sauvignon  Rating  0.556685  1.000000
# 4                 Chardonnay   Price  1.000000  0.429073
# 5                 Chardonnay  Rating  0.429073  1.000000
# 6                     Merlot   Price  1.000000  0.440685
# 7                     Merlot  Rating  0.440685  1.000000
# 8                 Pinot Noir   Price  1.000000  0.375345
# 9                 Pinot Noir  Rating  0.375345  1.000000
# 10                 Red Blend   Price  1.000000  0.462397
# 11                 Red Blend  Rating  0.462397  1.000000
# 12                  Riesling   Price  1.000000  0.397714
# 13                  Riesling  Rating  0.397714  1.000000
# 14                      Rosé   Price  1.000000  0.262412
# 15                      Rosé  Rating  0.262412  1.000000
# 16           Sauvignon Blanc   Price  1.000000  0.530771
# 17           Sauvignon Blanc  Rating  0.530771  1.000000
# 18                     Syrah   Price  1.000000  0.397914
# 19                     Syrah  Rating  0.397914  1.000000
